# %%
import import_ipynb
import os
#from mask_chin_class import *
from mask_class import *

# %%
folder_path = "observations-master/nomask"
#folder_path = "observations-master/experiements/data/without_mask"

images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
for i in range(len(images)):
    print("the path of the image is", images[i])
    create_mask(images[i])
# Out:
# the path of the image is observations-master/nomask\003050.jpg
# Save to observations-master/nomask\003050-with-kmask.jpg
# the path of the image is observations-master/nomask\003051.jpg
# Save to observations-master/nomask\003051-with-kmask.jpg
# the path of the image is observations-master/nomask\003052.jpg
# Save to observations-master/nomask\003052-with-kmask.jpg
# the path of the image is observations-master/nomask\003053.jpg
# Save to observations-master/nomask\003053-with-kmask.jpg
# the path of the image is observations-master/nomask\003054.jpg
# Save to observations-master/nomask\003054-with-kmask.jpg
# the path of the image is observations-master/nomask\003055.jpg
# Found no face.
# the path of the image is observations-master/nomask\003056.jpg
# Save to observations-master/nomask\003056-with-kmask.jpg
# the path of the image is observations-master/nomask\003057.jpg
# Save to observations-master/nomask\003057-with-kmask.jpg
# ...
